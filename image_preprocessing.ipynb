# %%
import cv2
from pathlib import Path

def apply_clahe(image, clip_limit=2.0, tile_grid_size=(8, 8)):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
    l = clahe.apply(l)
    updated_lab = cv2.merge((l, a, b))
    return cv2.cvtColor(updated_lab, cv2.COLOR_LAB2BGR)

def resize_and_preprocess_images(input_folder, output_folder, size=(416, 416), batch_size=100):
    input_path = Path(input_folder)
    output_path = Path(output_folder)
    output_path.mkdir(parents=True, exist_ok=True)
    
    images = list(input_path.glob('*.jpg'))
    total_images = len(images)
    num_batches = (total_images + batch_size - 1) // batch_size
    successful_saves = 0
    
    for i in range(num_batches):
        batch = images[i*batch_size:(i+1)*batch_size]
        for img_path in batch:
            img = cv2.imread(str(img_path))
            if img is None:
                print(f"Warning: Image {img_path} could not be loaded and will be skipped.")
                continue
            
            img_resized = cv2.resize(img, size, interpolation=cv2.INTER_LINEAR)
            img_clahe = apply_clahe(img_resized)
            
            output_img_path = output_path / img_path.name
            if cv2.imwrite(str(output_img_path), img_clahe):
                successful_saves += 1
            else:
                print(f"Error: Processed image {output_img_path} could not be saved.")

        print(f"Processed batch {i+1}/{num_batches}, successfully saved {successful_saves} images out of {len(batch)}")

    print(f"Total images processed: {total_images}, successfully saved {successful_saves} images.")

input_folder = 'bin_images'
output_folder = 'resized_images'
resize_and_preprocess_images(input_folder, output_folder, size=(416, 416))
# Out:
# Processed batch 1/100, successfully saved 100 images out of 100
# Processed batch 2/100, successfully saved 200 images out of 100
# Processed batch 3/100, successfully saved 300 images out of 100
# Processed batch 4/100, successfully saved 400 images out of 100
# Processed batch 5/100, successfully saved 500 images out of 100
# Processed batch 6/100, successfully saved 600 images out of 100
# Processed batch 7/100, successfully saved 700 images out of 100
# Processed batch 8/100, successfully saved 800 images out of 100
# Processed batch 9/100, successfully saved 900 images out of 100
# Processed batch 10/100, successfully saved 1000 images out of 100
# Processed batch 11/100, successfully saved 1100 images out of 100
# Processed batch 12/100, successfully saved 1200 images out of 100
# Processed batch 13/100, successfully saved 1300 images out of 100
# Processed batch 14/100, successfully saved 1400 images out of 100
# Processed batch 15/100, successfully saved 1500 images out of 100
# Processed batch 16/100, successfully saved 1600 images out of 100
# Processed batch 17/100, successfully saved 1700 images out of 100
# Processed batch 18/100, successfully saved 1800 images out of 100
# Processed batch 19/100, successfully saved 1900 images out of 100
# Processed batch 20/100, successfully saved 2000 images out of 100
# Processed batch 21/100, successfully saved 2100 images out of 100
# Processed batch 22/100, successfully saved 2200 images out of 100
# Processed batch 23/100, successfully saved 2300 images out of 100
# Processed batch 24/100, successfully saved 2400 images out of 100
# Processed batch 25/100, successfully saved 2500 images out of 100
# Processed batch 26/100, successfully saved 2600 images out of 100
# Processed batch 27/100, successfully saved 2700 images out of 100
# Processed batch 28/100, successfully saved 2800 images out of 100
# Processed batch 29/100, successfully saved 2900 images out of 100
# Processed batch 30/100, successfully saved 3000 images out of 100
# Processed batch 31/100, successfully saved 3100 images out of 100
# Processed batch 32/100, successfully saved 3200 images out of 100
# Processed batch 33/100, successfully saved 3300 images out of 100
# Processed batch 34/100, successfully saved 3400 images out of 100
# Processed batch 35/100, successfully saved 3500 images out of 100
# Processed batch 36/100, successfully saved 3600 images out of 100
# Processed batch 37/100, successfully saved 3700 images out of 100
# Processed batch 38/100, successfully saved 3800 images out of 100
# Processed batch 39/100, successfully saved 3900 images out of 100
# Processed batch 40/100, successfully saved 4000 images out of 100
# Processed batch 41/100, successfully saved 4100 images out of 100
# Processed batch 42/100, successfully saved 4200 images out of 100
# Processed batch 43/100, successfully saved 4300 images out of 100
# Processed batch 44/100, successfully saved 4400 images out of 100
# Processed batch 45/100, successfully saved 4500 images out of 100
# Processed batch 46/100, successfully saved 4600 images out of 100
# Processed batch 47/100, successfully saved 4700 images out of 100
# Processed batch 48/100, successfully saved 4800 images out of 100
# Processed batch 49/100, successfully saved 4900 images out of 100
# Processed batch 50/100, successfully saved 5000 images out of 100
# Processed batch 51/100, successfully saved 5100 images out of 100
# Processed batch 52/100, successfully saved 5200 images out of 100
# Processed batch 53/100, successfully saved 5300 images out of 100
# Processed batch 54/100, successfully saved 5400 images out of 100
# Processed batch 55/100, successfully saved 5500 images out of 100
# Processed batch 56/100, successfully saved 5600 images out of 100
# Processed batch 57/100, successfully saved 5700 images out of 100
# Processed batch 58/100, successfully saved 5800 images out of 100
# Processed batch 59/100, successfully saved 5900 images out of 100
# Processed batch 60/100, successfully saved 6000 images out of 100
# Processed batch 61/100, successfully saved 6100 images out of 100
# Processed batch 62/100, successfully saved 6200 images out of 100
# Processed batch 63/100, successfully saved 6300 images out of 100
# Processed batch 64/100, successfully saved 6400 images out of 100
# Processed batch 65/100, successfully saved 6500 images out of 100
# Processed batch 66/100, successfully saved 6600 images out of 100
# Processed batch 67/100, successfully saved 6700 images out of 100
# Processed batch 68/100, successfully saved 6800 images out of 100
# Processed batch 69/100, successfully saved 6900 images out of 100
# Processed batch 70/100, successfully saved 7000 images out of 100
# Processed batch 71/100, successfully saved 7100 images out of 100
# Processed batch 72/100, successfully saved 7200 images out of 100
# Processed batch 73/100, successfully saved 7300 images out of 100
# Processed batch 74/100, successfully saved 7400 images out of 100
# Processed batch 75/100, successfully saved 7500 images out of 100
# Processed batch 76/100, successfully saved 7600 images out of 100
# Processed batch 77/100, successfully saved 7700 images out of 100
# Processed batch 78/100, successfully saved 7800 images out of 100
# Processed batch 79/100, successfully saved 7900 images out of 100
# Processed batch 80/100, successfully saved 8000 images out of 100
# Processed batch 81/100, successfully saved 8100 images out of 100
# Processed batch 82/100, successfully saved 8200 images out of 100
# Processed batch 83/100, successfully saved 8300 images out of 100
# Processed batch 84/100, successfully saved 8400 images out of 100
# Processed batch 85/100, successfully saved 8500 images out of 100
# Processed batch 86/100, successfully saved 8600 images out of 100
# Processed batch 87/100, successfully saved 8700 images out of 100
# Processed batch 88/100, successfully saved 8800 images out of 100
# Processed batch 89/100, successfully saved 8900 images out of 100
# Processed batch 90/100, successfully saved 9000 images out of 100
# Processed batch 91/100, successfully saved 9100 images out of 100
# Processed batch 92/100, successfully saved 9200 images out of 100
# Processed batch 93/100, successfully saved 9300 images out of 100
# Processed batch 94/100, successfully saved 9400 images out of 100
# Processed batch 95/100, successfully saved 9500 images out of 100
# Processed batch 96/100, successfully saved 9600 images out of 100
# Processed batch 97/100, successfully saved 9700 images out of 100
# Processed batch 98/100, successfully saved 9800 images out of 100
# Processed batch 99/100, successfully saved 9900 images out of 100
# Processed batch 100/100, successfully saved 10000 images out of 100
# Total images processed: 10000, successfully saved 10000 images.

# %%
import cv2
import numpy as np
from pathlib import Path

def apply_laplacian_of_gaussian(image):
    # Apply Gaussian Blur
    blurred = cv2.GaussianBlur(image, (3, 3), 0)
    # Apply Laplacian
    laplacian = cv2.Laplacian(blurred, cv2.CV_64F)
    # Normalize the Laplacian image to combine with the original
    laplacian_norm = cv2.normalize(laplacian, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    # Combine original and enhanced edges
    enhanced_image = cv2.addWeighted(image, 0.85, laplacian_norm, 0.15, 0)
    return enhanced_image

def preprocess_images(input_folder, output_folder, size=(416, 416), batch_size=100):
    input_path = Path(input_folder)
    output_path = Path(output_folder)
    output_path.mkdir(parents=True, exist_ok=True)
    
    images = list(input_path.glob('*.jpg'))
    total_images = len(images)
    num_batches = (total_images + batch_size - 1) // batch_size
    successful_saves = 0
    
    for i in range(num_batches):
        batch = images[i*batch_size:(i+1)*batch_size]
        for img_path in batch:
            img = cv2.imread(str(img_path))
            if img is None:
                print(f"Warning: Image {img_path} could not be loaded and will be skipped.")
                continue
            
            img_enhanced = apply_laplacian_of_gaussian(img)
            
            output_img_path = output_path / img_path.name
            if cv2.imwrite(str(output_img_path), img_enhanced):
                successful_saves += 1
            else:
                print(f"Error: Processed image {output_img_path} could not be saved.")

        print(f"Processed batch {i+1}/{num_batches}, successfully saved {successful_saves} images out of {len(batch)}")

    print(f"Total images processed: {total_images}, successfully saved {successful_saves} images.")

# Define the input and output directories
input_folder = 'resized_images'
output_folder = 'processed_images'
preprocess_images(input_folder, output_folder)
# Out:
# Processed batch 1/100, successfully saved 100 images out of 100
# Processed batch 2/100, successfully saved 200 images out of 100
# Processed batch 3/100, successfully saved 300 images out of 100
# Processed batch 4/100, successfully saved 400 images out of 100
# Processed batch 5/100, successfully saved 500 images out of 100
# Processed batch 6/100, successfully saved 600 images out of 100
# Processed batch 7/100, successfully saved 700 images out of 100
# Processed batch 8/100, successfully saved 800 images out of 100
# Processed batch 9/100, successfully saved 900 images out of 100
# Processed batch 10/100, successfully saved 1000 images out of 100
# Processed batch 11/100, successfully saved 1100 images out of 100
# Processed batch 12/100, successfully saved 1200 images out of 100
# Processed batch 13/100, successfully saved 1300 images out of 100
# Processed batch 14/100, successfully saved 1400 images out of 100
# Processed batch 15/100, successfully saved 1500 images out of 100
# Processed batch 16/100, successfully saved 1600 images out of 100
# Processed batch 17/100, successfully saved 1700 images out of 100
# Processed batch 18/100, successfully saved 1800 images out of 100
# Processed batch 19/100, successfully saved 1900 images out of 100
# Processed batch 20/100, successfully saved 2000 images out of 100
# Processed batch 21/100, successfully saved 2100 images out of 100
# Processed batch 22/100, successfully saved 2200 images out of 100
# Processed batch 23/100, successfully saved 2300 images out of 100
# Processed batch 24/100, successfully saved 2400 images out of 100
# Processed batch 25/100, successfully saved 2500 images out of 100
# Processed batch 26/100, successfully saved 2600 images out of 100
# Processed batch 27/100, successfully saved 2700 images out of 100
# Processed batch 28/100, successfully saved 2800 images out of 100
# Processed batch 29/100, successfully saved 2900 images out of 100
# Processed batch 30/100, successfully saved 3000 images out of 100
# Processed batch 31/100, successfully saved 3100 images out of 100
# Processed batch 32/100, successfully saved 3200 images out of 100
# Processed batch 33/100, successfully saved 3300 images out of 100
# Processed batch 34/100, successfully saved 3400 images out of 100
# Processed batch 35/100, successfully saved 3500 images out of 100
# Processed batch 36/100, successfully saved 3600 images out of 100
# Processed batch 37/100, successfully saved 3700 images out of 100
# Processed batch 38/100, successfully saved 3800 images out of 100
# Processed batch 39/100, successfully saved 3900 images out of 100
# Processed batch 40/100, successfully saved 4000 images out of 100
# Processed batch 41/100, successfully saved 4100 images out of 100
# Processed batch 42/100, successfully saved 4200 images out of 100
# Processed batch 43/100, successfully saved 4300 images out of 100
# Processed batch 44/100, successfully saved 4400 images out of 100
# Processed batch 45/100, successfully saved 4500 images out of 100
# Processed batch 46/100, successfully saved 4600 images out of 100
# Processed batch 47/100, successfully saved 4700 images out of 100
# Processed batch 48/100, successfully saved 4800 images out of 100
# Processed batch 49/100, successfully saved 4900 images out of 100
# Processed batch 50/100, successfully saved 5000 images out of 100
# Processed batch 51/100, successfully saved 5100 images out of 100
# Processed batch 52/100, successfully saved 5200 images out of 100
# Processed batch 53/100, successfully saved 5300 images out of 100
# Processed batch 54/100, successfully saved 5400 images out of 100
# Processed batch 55/100, successfully saved 5500 images out of 100
# Processed batch 56/100, successfully saved 5600 images out of 100
# Processed batch 57/100, successfully saved 5700 images out of 100
# Processed batch 58/100, successfully saved 5800 images out of 100
# Processed batch 59/100, successfully saved 5900 images out of 100
# Processed batch 60/100, successfully saved 6000 images out of 100
# Processed batch 61/100, successfully saved 6100 images out of 100
# Processed batch 62/100, successfully saved 6200 images out of 100
# Processed batch 63/100, successfully saved 6300 images out of 100
# Processed batch 64/100, successfully saved 6400 images out of 100
# Processed batch 65/100, successfully saved 6500 images out of 100
# Processed batch 66/100, successfully saved 6600 images out of 100
# Processed batch 67/100, successfully saved 6700 images out of 100
# Processed batch 68/100, successfully saved 6800 images out of 100
# Processed batch 69/100, successfully saved 6900 images out of 100
# Processed batch 70/100, successfully saved 7000 images out of 100
# Processed batch 71/100, successfully saved 7100 images out of 100
# Processed batch 72/100, successfully saved 7200 images out of 100
# Processed batch 73/100, successfully saved 7300 images out of 100
# Processed batch 74/100, successfully saved 7400 images out of 100
# Processed batch 75/100, successfully saved 7500 images out of 100
# Processed batch 76/100, successfully saved 7600 images out of 100
# Processed batch 77/100, successfully saved 7700 images out of 100
# Processed batch 78/100, successfully saved 7800 images out of 100
# Processed batch 79/100, successfully saved 7900 images out of 100
# Processed batch 80/100, successfully saved 8000 images out of 100
# Processed batch 81/100, successfully saved 8100 images out of 100
# Processed batch 82/100, successfully saved 8200 images out of 100
# Processed batch 83/100, successfully saved 8300 images out of 100
# Processed batch 84/100, successfully saved 8400 images out of 100
# Processed batch 85/100, successfully saved 8500 images out of 100
# Processed batch 86/100, successfully saved 8600 images out of 100
# Processed batch 87/100, successfully saved 8700 images out of 100
# Processed batch 88/100, successfully saved 8800 images out of 100
# Processed batch 89/100, successfully saved 8900 images out of 100
# Processed batch 90/100, successfully saved 9000 images out of 100
# Processed batch 91/100, successfully saved 9100 images out of 100
# Processed batch 92/100, successfully saved 9200 images out of 100
# Processed batch 93/100, successfully saved 9300 images out of 100
# Processed batch 94/100, successfully saved 9400 images out of 100
# Processed batch 95/100, successfully saved 9500 images out of 100
# Processed batch 96/100, successfully saved 9600 images out of 100
# Processed batch 97/100, successfully saved 9700 images out of 100
# Processed batch 98/100, successfully saved 9800 images out of 100
# Processed batch 99/100, successfully saved 9900 images out of 100
# Processed batch 100/100, successfully saved 10000 images out of 100
# Total images processed: 10000, successfully saved 10000 images.
